# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import peak_signal_noise_ratio as psnr

# %%
lr_path = "../data/processed/DIV2K/DIV2K_train_LR_x8/0006.png"
hr_path = "../data/raw/DIV2K/DIV2K_train_HR/0006.png"

# %%
lr = Image.open(lr_path)
hr = Image.open(hr_path)

# %%
lr_up = lr.resize(hr.size, resample=Image.BICUBIC)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 15))

axes[0].imshow(hr)
axes[0].set_title('HR Image')
axes[0].axis('off')

axes[1].imshow(lr)
axes[1].set_title('LR Image')
axes[1].axis('off')

axes[2].imshow(lr_up)
axes[2].set_title('LR Up Image')
axes[2].axis('off')

plt.tight_layout()
plt.show()

# %%
psnr_val = psnr(np.array(hr), np.array(lr_up))
print("PSNR bicubic:", psnr_val)
# Out:
# PSNR bicubic: 25.908393248871192
